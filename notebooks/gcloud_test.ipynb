# %%
import os
import google.auth
from google.oauth2 import service_account
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# Set up the API key and project ID for Gemini 
PROJECT_ID = os.environ['GCP_PROJECT_ID']

#credentials, project_id = google.auth.default()

# If you want to explicitly specify the service account key file:
credentials = service_account.Credentials.from_service_account_file(
    "../pacific-ethos-428312-n5-eb4864ff3add.json"
)

vertexai.init(project=PROJECT_ID, credentials=credentials, location="us-central1")

# %%
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting


def generate():
    model = GenerativeModel(
        "gemini-1.5-flash-001",
    )
    responses = model.generate_content(
        "What's a good name for a flower shop that specializes in selling bouquets of dried flowers?",
        generation_config=generation_config,
        safety_settings=safety_settings,
        stream=True,
    )

    for response in responses:
        print(response.text, end="")


generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = [
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE
    ),
]

generate()
# Out:
# Here are some names for a flower shop specializing in dried flowers, playing with different themes:
#
# **Whimsical & Romantic:**
#
# * Whispering Blooms
# * The Dried Petal
# * Everlasting Blooms
# * Botanical Echoes
# * Dried & Delightful
# * Bloom & Bloom Again
#
# **Elegant & Classic:**
#
# * The Dried Garden
# * Timeless Blooms
# * The Bloomery
# * Flora Eternal
# * The Dried Flower Studio
# * The Bloom Preserve
#
# **Modern & Trendy:**
#
# * The Bloom Bar
# * The Dried Bouquet
# * Botanical Co.
# * Bloom & Gather
# * The Flower Lab
# * Petal & Stem
#
# **Unique & Playful:**
#
# * The Paper Flower
# * The Forever Bouquet
# * The Dusty Bloom
# * The Dried & Wild
# * Bloom Forever
# * The Petal Pantry
#
# **Location-Based:**
#
# * [City Name] Dried Flowers
# * [Neighborhood Name] Blooms
# * The [Local Landmark] Bouquet
#
# **Tips for Choosing a Name:**
#
# * **Consider your target audience:** Who are you trying to reach with your brand?
# * **Keep it memorable and easy to say:** A catchy name will stick in people's minds.
# * **Make sure the name is available as a website domain and social media handle.**
# * **Check if the name is already being used by another business.**
#
# **Bonus:** You could also incorporate a play on words or a pun related to dried flowers. For example, "The Dried and True" or "Flower Power, Forever."
#
# Ultimately, the best name for your flower shop is one that you love and that reflects your brand's personality.
